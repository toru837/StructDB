# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('employee_contact.xlsx')

# %%
df.head()
# Out:
#    Staff Member      Corporate Email     City        Mobile  \
# 0   riya thomas   riya.t@company.com  Chennai           NaN
# 1   Neha  Gupta   neha.g@company.com    Noida           NaN
# 2  Sneha Kapoor  sneha.k@company.com   Mumbai  9.876501e+09
#
#                 Role Department Name_x  Contact Number_x Current Status_x  \
# 0    Product Manager           Product      9.876501e+09           Active
# 1          Recruiter                HR      9.876501e+09           Active
# 2  Finance Associate           Finance      9.876501e+09           Active
#
#   Employee Code_x Department Name_y  Contact Number_y Current Status_y  \
# 0          EMP112           Product      9.876501e+09           Active
# 1          EMP108                HR      9.876501e+09           Active
# 2          EMP104           Finance      9.876501e+09           Active
#
#   Employee Code_y Department Name  Contact Number Current Status Employee Code
# ...

# %%
df2=pd.read_excel('employee_department.xlsx')

# %%
df3=pd.read_excel('employee_master.xlsx')

# %%
df2.head(2)
# Out:
#       Associate Department Name  Contact Number Current Status Employee Code
# 0  anjali singh          Design             NaN         Active        EMP106
# 1   Neha  Gupta              HR    9.876501e+09         Active        EMP108

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Associate        12 non-null     object
#  1   Department Name  12 non-null     object
#  2   Contact Number   8 non-null      float64
#  3   Current Status   12 non-null     object
#  4   Employee Code    12 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 612.0+ bytes

# %%
# df.merge(df2, left_on='Mobile', right_on='Contact Number', how='left')

# %%
df.isnull().sum() #we can remove or might be there in other excel sheet
# Out:
# Staff Member       0
# Corporate Email    0
# City               0
# Mobile             6
# Role               0
# dtype: int64

# %%
for col in df.columns:
    print(f"Unique values in {col}: {df[col].nunique()}")   #any of them can be pk
# Out:
# Unique values in Staff Member: 12
# Unique values in Corporate Email: 12
# Unique values in City: 12
# Unique values in Mobile: 6
# Unique values in Role: 12

# %%
for col in df2.columns:
    print(f"Unique values in {col}: {df2[col].nunique()}")   #any of them can be pk
# Out:
# Unique values in Associate: 12
# Unique values in Department Name: 8
# Unique values in Contact Number: 8
# Unique values in Current Status: 3
# Unique values in Employee Code: 12

# %%
df2=df2.rename(columns={'Associate':'Staff Member'})

# %%
df2.head()
# Out:
#    Staff Member Department Name  Contact Number Current Status Employee Code
# 0  anjali singh          Design             NaN         Active        EMP106
# 1   Neha  Gupta              HR    9.876501e+09         Active        EMP108
# 2   Rahul Verma       Analytics    9.876501e+09       On Leave        EMP103
# 3    Pooja Jain              IT             NaN         Active        EMP110
# 4     ARJUN DAS       Analytics    9.876501e+09       Inactive        EMP111

# %%
#df=pd.merge(df,df2,on="Staff Member")
#df=df.merge(df2,on="Staff Member")

# %%
df = pd.read_excel('employee_contact.xlsx')
df.head()
# Out:
#    Staff Member          Corporate Email       City        Mobile  \
# 0  Karan  Patel      karan.p@company.com  Ahmedabad           NaN
# 1     Arjun Das      arjun.d@company.com    Kolkata  9.876501e+09
# 2  Anjali Singh     anjali.s@company.com       Pune           NaN
# 3   RAHUL VERMA  rahul.verma@company.com      Delhi  9.876501e+09
# 4   riya thomas       riya.t@company.com    Chennai           NaN
#
#                Role
# 0    Marketing Lead
# 1  Business Analyst
# 2       UI Designer
# 3      Data Analyst
# 4   Product Manager

# %%
df['Staff Member'] = df['Staff Member'].str.lower()
df2['Staff Member'] = df2['Staff Member'].str.lower()

# %%
df_merged = df.merge(df2, on='Staff Member', how='left')
df_merged.head()
# Out:
#    Staff Member          Corporate Email       City        Mobile  \
# 0  karan  patel      karan.p@company.com  Ahmedabad           NaN
# 1     arjun das      arjun.d@company.com    Kolkata  9.876501e+09
# 2  anjali singh     anjali.s@company.com       Pune           NaN
# 3   rahul verma  rahul.verma@company.com      Delhi  9.876501e+09
# 4   riya thomas       riya.t@company.com    Chennai           NaN
#
#                Role Department Name  Contact Number Current Status  \
# 0    Marketing Lead             NaN             NaN            NaN
# 1  Business Analyst       Analytics    9.876501e+09       Inactive
# 2       UI Designer          Design             NaN         Active
# 3      Data Analyst       Analytics    9.876501e+09       On Leave
# 4   Product Manager         Product    9.876501e+09         Active
#
#   Employee Code
# 0           NaN
# 1        EMP111
# 2        EMP106
# 3        EMP103
# 4        EMP112

# %%
df_merged.shape
# Out:
# (12, 9)

# %%
#i can not just remove one of the same column because some of  them ve null some do not
#df_merged.remove(columns={'Mobile	',''})

# %%
df_merged["merge_job"] = df_merged["Department Name"].combine_first(df_merged["Role"])

# %%
df_merged.sample(5)
# Out:
#     Staff Member          Corporate Email       City        Mobile  \
# 8   mohit sharma      mohit.s@company.com     Jaipur           NaN
# 9     pooja jain      pooja.j@company.com     Indore  9.876501e+09
# 0   karan  patel      karan.p@company.com  Ahmedabad           NaN
# 7    aarav mehta  aarav.mehta@company.com  Bengaluru  9.876501e+09
# 11  sneha kapoor      sneha.k@company.com     Mumbai  9.876501e+09
#
#                  Role Department Name  Contact Number Current Status  \
# 8       Sales Manager             NaN             NaN            NaN
# 9         QA Engineer              IT             NaN         Active
# 0      Marketing Lead             NaN             NaN            NaN
# 7   Software Engineer             NaN             NaN            NaN
# 11  Finance Associate         Finance    9.876501e+09         Active
#
#    Employee Code          merge_job
# 8            NaN      Sales Manager
# 9         EMP110                 IT
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Staff Member     12 non-null     object
#  1   Corporate Email  12 non-null     object
#  2   City             12 non-null     object
#  3   Mobile           6 non-null      float64
#  4   Role             12 non-null     object
#  5   Department Name  8 non-null      object
#  6   Contact Number   6 non-null      float64
#  7   Current Status   8 non-null      object
#  8   Employee Code    8 non-null      object
#  9   merge_job        12 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 1.1+ KB

# %%
df_merged["merged_contact_number"] = df_merged["Mobile"].combine_first(df_merged["Contact Number"])

# %%
df_merged.head()
# Out:
#    Staff Member          Corporate Email       City        Mobile  \
# 0  karan  patel      karan.p@company.com  Ahmedabad           NaN
# 1     arjun das      arjun.d@company.com    Kolkata  9.876501e+09
# 2  anjali singh     anjali.s@company.com       Pune           NaN
# 3   rahul verma  rahul.verma@company.com      Delhi  9.876501e+09
# 4   riya thomas       riya.t@company.com    Chennai           NaN
#
#                Role Department Name  Contact Number Current Status  \
# 0    Marketing Lead             NaN             NaN            NaN
# 1  Business Analyst       Analytics    9.876501e+09       Inactive
# 2       UI Designer          Design             NaN         Active
# 3      Data Analyst       Analytics    9.876501e+09       On Leave
# 4   Product Manager         Product    9.876501e+09         Active
#
#   Employee Code       merge_job  merged_contact_number
# 0           NaN  Marketing Lead                    NaN
# ...

# %%
df_merged.drop(columns=['Mobile','Contact Number','Department Name','Role'], inplace=True)

# %%
df_merged.head()
# Out:
#    Staff Member          Corporate Email       City Current Status  \
# 0  karan  patel      karan.p@company.com  Ahmedabad            NaN
# 1     arjun das      arjun.d@company.com    Kolkata       Inactive
# 2  anjali singh     anjali.s@company.com       Pune         Active
# 3   rahul verma  rahul.verma@company.com      Delhi       On Leave
# 4   riya thomas       riya.t@company.com    Chennai         Active
#
#   Employee Code       merge_job  merged_contact_number
# 0           NaN  Marketing Lead                    NaN
# 1        EMP111       Analytics           9.876501e+09
# 2        EMP106          Design                    NaN
# 3        EMP103       Analytics           9.876501e+09
# 4        EMP112         Product           9.876501e+09

# %%
df3.head()
# Out:
#   Employee Full Name Employee ID     Designation Office Location  \
# 0         NEHA GUPTA      EMP108       Recruiter           Noida
# 1       anjali singh      EMP106     UI Designer            Pune
# 2       Rahul  Verma      EMP103    Data Analyst           Delhi
# 3        Karan Patel      EMP109  Marketing Lead       Ahmedabad
# 4         Pooja Jain      EMP110     QA Engineer          Indore
#
#                 Work Email
# 0       neha.g@company.com
# 1     anjali.s@company.com
# 2  rahul.verma@company.com
# 3      karan.p@company.com
# 4      pooja.j@company.com

# %%
df3['Employee ID'].nunique()
# Out:
# 12

# %%
df3=df3.rename(columns={'Employee ID':'Employee Code'})

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Staff Member           12 non-null     object
#  1   Corporate Email        12 non-null     object
#  2   City                   12 non-null     object
#  3   Current Status         8 non-null      object
#  4   Employee Code          8 non-null      object
#  5   merge_job              12 non-null     object
#  6   merged_contact_number  9 non-null      float64
# dtypes: float64(1), object(6)
# memory usage: 804.0+ bytes

# %%
df_merged_2 = df_merged.merge(df3, on='Employee Code', how='left')
df_merged_2.head()
# Out:
#    Staff Member          Corporate Email       City Current Status  \
# 0  karan  patel      karan.p@company.com  Ahmedabad            NaN
# 1     arjun das      arjun.d@company.com    Kolkata       Inactive
# 2  anjali singh     anjali.s@company.com       Pune         Active
# 3   rahul verma  rahul.verma@company.com      Delhi       On Leave
# 4   riya thomas       riya.t@company.com    Chennai         Active
#
#   Employee Code       merge_job  merged_contact_number Employee Full Name  \
# 0           NaN  Marketing Lead                    NaN                NaN
# 1        EMP111       Analytics           9.876501e+09          arjun das
# 2        EMP106          Design                    NaN       anjali singh
# 3        EMP103       Analytics           9.876501e+09       Rahul  Verma
# 4        EMP112         Product           9.876501e+09        riya thomas
#
#         Designation Office Location               Work Email
# ...

# %%
df_merged_2.drop(columns=['Employee Full Name','Designation','Office Location','Work Email'], inplace=True)

# %%
df_merged_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Staff Member           12 non-null     object
#  1   Corporate Email        12 non-null     object
#  2   City                   12 non-null     object
#  3   Current Status         8 non-null      object
#  4   Employee Code          8 non-null      object
#  5   merge_job              12 non-null     object
#  6   merged_contact_number  9 non-null      float64
# dtypes: float64(1), object(6)
# memory usage: 804.0+ bytes

# %%
df_merged_2.head()
# Out:
#    Staff Member          Corporate Email       City Current Status  \
# 0  karan  patel      karan.p@company.com  Ahmedabad            NaN
# 1     arjun das      arjun.d@company.com    Kolkata       Inactive
# 2  anjali singh     anjali.s@company.com       Pune         Active
# 3   rahul verma  rahul.verma@company.com      Delhi       On Leave
# 4   riya thomas       riya.t@company.com    Chennai         Active
#
#   Employee Code       merge_job  merged_contact_number
# 0           NaN  Marketing Lead                    NaN
# 1        EMP111       Analytics           9.876501e+09
# 2        EMP106          Design                    NaN
# 3        EMP103       Analytics           9.876501e+09
# 4        EMP112         Product           9.876501e+09

# %%
#now combine excel sheet is here i can convert it into db or use it normally
#deciision making should i remove all null value columns everything on me
#i can add some constrains
#if employee code is not there remove that person
#contact to 0

# %%
#we can perform EDA to visualize things
